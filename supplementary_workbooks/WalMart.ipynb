# %%
import thinkplot
import thinkstats2
import pandas as pd
import numpy as np
import scipy.stats as ss
from fractions import Fraction

##Seaborn for fancy plots. 
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (15,5)

# %%
df = pd.read_csv("WalMartSales.csv")
#df = df.replace(',','', regex=True)
#df["Avg. Weekly Sales"] = pd.to_numeric(df["Avg. Weekly Sales"])
#df["Avg. Size"] = pd.to_numeric(df["Avg. Size"])
#pd.to_numeric(df["Avg. Weekly Sales"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ﻿Store        6435 non-null   float64
#  1   FuelPrice     6435 non-null   float64
#  2   StoreSize     6435 non-null   float64
#  3   WeekAvgTemp   6435 non-null   float64
#  4   Unemployment  6435 non-null   float64
#  5   Sales         6435 non-null   float64
#  6   SalesPerSqFt  6435 non-null   float64
# dtypes: float64(7)
# memory usage: 352.0 KB

# %%
sns.pairplot(df)

# %%
thinkplot.PrePlot(2,1,2)
sns.histplot(df, x="Sales", binwidth=5000, stat="density")
thinkplot.SubPlot(2)
sns.histplot(df, x="Sales", binwidth=5000, stat="probability")
thinkplot.Config()
